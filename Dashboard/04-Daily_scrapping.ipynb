# %% [markdown]
# # Daily Scrapping

# %% [markdown]
# This notebook a routine to scrap the data from Yahoo daily

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from datetime import datetime
import numpy as np
import pandas as pd

from dashboards.yahoo_parser import YahooParser

# %% [markdown]
# ## Get the Portfolio

# %% [markdown]
# To get the tickers in the portfolio, we are going to export the "Posição na Carteira" table from `statusinvest`.<br>
# https://statusinvest.com.br/carteira/patrimonio

# %%
columns={'ATIVO': 'Ticker', 'PREÇO MÉDIO': 'AvgPrice', 'PREÇO ATUAL': 'Price', 'QUANTIDADE': 'Qty'}
portfolio = pd.read_csv('CarteiraStatusInvest.csv', encoding='utf-8', sep=';', decimal=',')[columns.keys()]
portfolio = portfolio.rename(columns=columns)
portfolio['Qty'] = portfolio['Qty'].astype('int')
portfolio['AvgPrice'] = portfolio['AvgPrice'].round(2)
portfolio
# Out:
#     Ticker  AvgPrice  Price   Qty     Volume
# 0    ABCB4     14.61  23.21  3128   72600.88
# 1    AGRO3     26.17  26.72   500   13360.00
# 2    AURE3     11.79  11.11  3200   35552.00
# 3    BBAS3     21.28  28.35  4950  140332.50
# 4    BBSE3     28.81  36.42  3700  134754.00
# 5    BLAU3     26.45  13.95   500    6975.00
# 6   BRBI11     16.15  15.80   700   11060.00
# 7    BRKM5     29.85  18.19   900   16371.00
# 8    CSAN3     13.63  13.06  1100   14366.00
# 9    EGIE3     33.90  44.13  1300   57369.00
# 10   ELET6     46.05  46.17   400   18468.00
# 11   ETER3     10.22   5.81  3250   18882.50
# 12   EZTC3     16.37  14.22  1000   14220.00
# 13   FLRY3     23.18  16.68  2100   35028.00
# 14   IRBR3     50.84  47.74   345   16470.30
# 15   ITSA3     10.61  11.24  4273   48028.52
# 16   ITSA4     10.46  11.25  1827   20553.75
# 17  KLBN11     18.81  21.71  3580   77721.80
# 18   LEVE3     24.13  30.85   500   15425.00
# 19   MOVI3     19.44   7.05  1000    7050.00
# 20   NEOE3     17.24  19.50  1100   21450.00
# 21   PETR3     14.79  40.82   100    4082.00
# 22   PETR4     34.34  37.18   300   11154.00
# 23   RDOR3     44.93  34.07   229    7802.03
# 24   SANB3     13.46  14.66  4500   65970.00
# 25  TAEE11     27.19  35.26  2600   91676.00
# 26   TASA4     12.87  11.18  3200   35776.00
# 27   TRPL4     23.00  24.85  1600   39760.00
# 28   TTEN3      9.85  12.33  1800   22194.00
# 29   UNIP6     49.66  47.20   400   18880.00
# 30   VALE3     67.80  58.15  1440   83736.00
# 31   VIVT3     36.77  55.27   500   27635.00
# 32   WIZC3      8.63   5.99  2200   13178.00

# %%
yahoo = YahooParser(headless=True)

alternate_tickers = {'ITSA3': {'ticker': 'ITSA4'}, 'SANB3': {'ticker': 'SANB11', 'factor': 0.5}}

results = yahoo.get_tickers(portfolio['Ticker'].iloc[:2], alternate_tickers=alternate_tickers)
# Out:
# Fetching ticker ABCB4
# Fetching ticker AGRO3

# %%
results
# Out:
#        quote  recomendation    low   mean  high  analists
# ABCB4  23.60            2.5  21.83  25.02  28.0       8.0
# AGRO3  26.92            2.5  29.70  36.35  43.0       2.0

# %%
portfolio = pd.concat([portfolio.set_index('Ticker'), results], axis=1)

# %%
portfolio['Price'] = portfolio['quote']
portfolio = portfolio.drop(columns='quote')
portfolio['Volume'] = portfolio['Qty'] * portfolio['Price']

# %%
portfolio
# Out:
#         AvgPrice  Price   Qty   Volume  recomendation    low   mean  high  \
# ABCB4      14.61  23.60  3128  73820.8            2.5  21.83  25.02  28.0
# AGRO3      26.17  26.92   500  13460.0            2.5  29.70  36.35  43.0
# AURE3      11.79    NaN  3200      NaN            NaN    NaN    NaN   NaN
# BBAS3      21.28    NaN  4950      NaN            NaN    NaN    NaN   NaN
# BBSE3      28.81    NaN  3700      NaN            NaN    NaN    NaN   NaN
# BLAU3      26.45    NaN   500      NaN            NaN    NaN    NaN   NaN
# BRBI11     16.15    NaN   700      NaN            NaN    NaN    NaN   NaN
# BRKM5      29.85    NaN   900      NaN            NaN    NaN    NaN   NaN
# CSAN3      13.63    NaN  1100      NaN            NaN    NaN    NaN   NaN
# EGIE3      33.90    NaN  1300      NaN            NaN    NaN    NaN   NaN
# ELET6      46.05    NaN   400      NaN            NaN    NaN    NaN   NaN
# ETER3      10.22    NaN  3250      NaN            NaN    NaN    NaN   NaN
# EZTC3      16.37    NaN  1000      NaN            NaN    NaN    NaN   NaN
# FLRY3      23.18    NaN  2100      NaN            NaN    NaN    NaN   NaN
# IRBR3      50.84    NaN   345      NaN            NaN    NaN    NaN   NaN
# ITSA3      10.61    NaN  4273      NaN            NaN    NaN    NaN   NaN
# ITSA4      10.46    NaN  1827      NaN            NaN    NaN    NaN   NaN
# KLBN11     18.81    NaN  3580      NaN            NaN    NaN    NaN   NaN
# LEVE3      24.13    NaN   500      NaN            NaN    NaN    NaN   NaN
# MOVI3      19.44    NaN  1000      NaN            NaN    NaN    NaN   NaN
# NEOE3      17.24    NaN  1100      NaN            NaN    NaN    NaN   NaN
# PETR3      14.79    NaN   100      NaN            NaN    NaN    NaN   NaN
# PETR4      34.34    NaN   300      NaN            NaN    NaN    NaN   NaN
# RDOR3      44.93    NaN   229      NaN            NaN    NaN    NaN   NaN
# SANB3      13.46    NaN  4500      NaN            NaN    NaN    NaN   NaN
# TAEE11     27.19    NaN  2600      NaN            NaN    NaN    NaN   NaN
# TASA4      12.87    NaN  3200      NaN            NaN    NaN    NaN   NaN
# TRPL4      23.00    NaN  1600      NaN            NaN    NaN    NaN   NaN
# TTEN3       9.85    NaN  1800      NaN            NaN    NaN    NaN   NaN
# UNIP6      49.66    NaN   400      NaN            NaN    NaN    NaN   NaN
# VALE3      67.80    NaN  1440      NaN            NaN    NaN    NaN   NaN
# VIVT3      36.77    NaN   500      NaN            NaN    NaN    NaN   NaN
# WIZC3       8.63    NaN  2200      NaN            NaN    NaN    NaN   NaN
#
#         analists
# ABCB4        8.0
# AGRO3        2.0
# AURE3        NaN
# BBAS3        NaN
# BBSE3        NaN
# BLAU3        NaN
# BRBI11       NaN
# BRKM5        NaN
# CSAN3        NaN
# EGIE3        NaN
# ELET6        NaN
# ETER3        NaN
# EZTC3        NaN
# FLRY3        NaN
# IRBR3        NaN
# ITSA3        NaN
# ITSA4        NaN
# KLBN11       NaN
# LEVE3        NaN
# MOVI3        NaN
# NEOE3        NaN
# PETR3        NaN
# PETR4        NaN
# RDOR3        NaN
# SANB3        NaN
# TAEE11       NaN
# TASA4        NaN
# TRPL4        NaN
# TTEN3        NaN
# UNIP6        NaN
# VALE3        NaN
# VIVT3        NaN
# WIZC3        NaN

# %%
portfolio['analists'] = portfolio['analists'].replace('', 0).fillna(0).astype('int')

portfolio
# Out:
#         AvgPrice  Price   Qty     Volume  recomendation    low   mean  high  \
# ABCB4      14.61  23.21  3128   72600.88            2.5  21.83  25.02  28.0
# AGRO3      26.17  26.72   500   13360.00            2.5  29.70  36.35  43.0
# AURE3      11.79  11.11  3200   35552.00            NaN    NaN    NaN   NaN
# BBAS3      21.28  28.35  4950  140332.50            NaN    NaN    NaN   NaN
# BBSE3      28.81  36.42  3700  134754.00            NaN    NaN    NaN   NaN
# BLAU3      26.45  13.95   500    6975.00            NaN    NaN    NaN   NaN
# BRBI11     16.15  15.80   700   11060.00            NaN    NaN    NaN   NaN
# BRKM5      29.85  18.19   900   16371.00            NaN    NaN    NaN   NaN
# CSAN3      13.63  13.06  1100   14366.00            NaN    NaN    NaN   NaN
# EGIE3      33.90  44.13  1300   57369.00            NaN    NaN    NaN   NaN
# ELET6      46.05  46.17   400   18468.00            NaN    NaN    NaN   NaN
# ETER3      10.22   5.81  3250   18882.50            NaN    NaN    NaN   NaN
# EZTC3      16.37  14.22  1000   14220.00            NaN    NaN    NaN   NaN
# FLRY3      23.18  16.68  2100   35028.00            NaN    NaN    NaN   NaN
# IRBR3      50.84  47.74   345   16470.30            NaN    NaN    NaN   NaN
# ITSA3      10.61  11.24  4273   48028.52            NaN    NaN    NaN   NaN
# ITSA4      10.46  11.25  1827   20553.75            NaN    NaN    NaN   NaN
# KLBN11     18.81  21.71  3580   77721.80            NaN    NaN    NaN   NaN
# LEVE3      24.13  30.85   500   15425.00            NaN    NaN    NaN   NaN
# MOVI3      19.44   7.05  1000    7050.00            NaN    NaN    NaN   NaN
# NEOE3      17.24  19.50  1100   21450.00            NaN    NaN    NaN   NaN
# PETR3      14.79  40.82   100    4082.00            NaN    NaN    NaN   NaN
# PETR4      34.34  37.18   300   11154.00            NaN    NaN    NaN   NaN
# RDOR3      44.93  34.07   229    7802.03            NaN    NaN    NaN   NaN
# SANB3      13.46  14.66  4500   65970.00            NaN    NaN    NaN   NaN
# TAEE11     27.19  35.26  2600   91676.00            NaN    NaN    NaN   NaN
# TASA4      12.87  11.18  3200   35776.00            NaN    NaN    NaN   NaN
# TRPL4      23.00  24.85  1600   39760.00            NaN    NaN    NaN   NaN
# TTEN3       9.85  12.33  1800   22194.00            NaN    NaN    NaN   NaN
# UNIP6      49.66  47.20   400   18880.00            NaN    NaN    NaN   NaN
# VALE3      67.80  58.15  1440   83736.00            NaN    NaN    NaN   NaN
# VIVT3      36.77  55.27   500   27635.00            NaN    NaN    NaN   NaN
# WIZC3       8.63   5.99  2200   13178.00            NaN    NaN    NaN   NaN
#
#         analists
# ABCB4          8
# AGRO3          2
# AURE3          0
# BBAS3          0
# BBSE3          0
# BLAU3          0
# BRBI11         0
# BRKM5          0
# CSAN3          0
# EGIE3          0
# ELET6          0
# ETER3          0
# EZTC3          0
# FLRY3          0
# IRBR3          0
# ITSA3          0
# ITSA4          0
# KLBN11         0
# LEVE3          0
# MOVI3          0
# NEOE3          0
# PETR3          0
# PETR4          0
# RDOR3          0
# SANB3          0
# TAEE11         0
# TASA4          0
# TRPL4          0
# TTEN3          0
# UNIP6          0
# VALE3          0
# VIVT3          0
# WIZC3          0

# %%
portfolio = portfolio.replace('', np.nan)	
portfolio['Date'] = datetime.now().strftime('%Y-%m-%d')
portfolio['Upside'] = (portfolio['mean'] / portfolio['Price']) - 1

# %%
portfolio['Upside'] = ((100*portfolio['Upside']).round(1)).astype('str') + '%'

# %%
portfolio.reset_index().rename(columns={'index': 'Stock'})\
    .to_json(f'./data/portfolio_{datetime.now().strftime("%Y%m%d")}.json', orient='records')

# %%
pd.read_json(f'./data/portfolio_{datetime.now().strftime("%Y%m%d")}.json', orient='records')
# Out:
#      Stock  AvgPrice  Price   Qty     Volume  recomendation     low    mean  \
# 0    ABCB4     14.61  23.21  3128   72600.88            2.5  21.830  25.020
# 1    AGRO3     26.17  26.72   500   13360.00            2.5  29.700  36.350
# 2    AURE3     11.79  11.11  3200   35552.00            2.6  12.000  14.720
# 3    BBAS3     21.28  28.35  4950  140332.50            1.8  17.500  34.000
# 4    BBSE3     28.81  36.42  3700  134754.00            2.7  30.000  37.150
# 5    BLAU3     26.45  13.95   500    6975.00            3.3  12.000  16.550
# 6   BRBI11     16.15  15.80   700   11060.00            1.8  18.000  19.140
# 7    BRKM5     29.85  18.19   900   16371.00            2.7  20.000  26.390
# 8    CSAN3     13.63  13.06  1100   14366.00            2.2  16.500  23.690
# 9    EGIE3     33.90  44.13  1300   57369.00            3.3  38.000  44.150
# 10   ELET6     46.05  46.17   400   18468.00            1.9  53.000  58.070
# 11   ETER3     10.22   5.81  3250   18882.50            3.0     NaN     NaN
# 12   EZTC3     16.37  14.22  1000   14220.00            3.1  14.000  19.890
# 13   FLRY3     23.18  16.68  2100   35028.00            2.4  16.000  19.060
